# %% [markdown]
# ---
# ### Integrated Customer Segmentation Processing
# ---

# %%
import pandas as pd

class CustomerSegmentationProcessor:
    def __init__(self, rfm_path, churn_path, merge_on, column_mappings):
        self.rfm_path = rfm_path
        self.churn_path = churn_path
        self.merge_on = merge_on
        self.column_mappings = column_mappings

    def process(self):
        rfm_data = pd.read_csv(self.rfm_path, low_memory=False)
        churn_data = pd.read_csv(self.churn_path, low_memory=False)

        combined_data = pd.merge(churn_data, rfm_data, on=self.merge_on, how='outer')

        combined_data.rename(columns=self.column_mappings, inplace=True)

        required_columns = [
            'id', 'MembershipStatus', 'FirstTransactionDate', 'LastTransactionDate',
            'DaysSinceLastTransaction', 'ChurnStatus', 'RecencyScore',
            'FrequencyScore', 'MonetaryScore', 'RFMScore', 'Segment', 'SegmentDescription'
        ]

        return combined_data[required_columns]

column_names_mapping = {
    'R': 'RecencyScore',
    'F': 'FrequencyScore',
    'M': 'MonetaryScore',
    'RFM_Segment': 'RFMSegment',
    'RFM_Score': 'RFMScore',
    'Status': 'Segment',
    'Description': 'SegmentDescription'
}

processor = CustomerSegmentationProcessor(
    rfm_path='data/Customer_rfm.csv',
    churn_path='data/churn_analysis.csv',
    merge_on='id',
    column_mappings=column_names_mapping
)

result_df = processor.process()
result_df
# Out:
#            id MembershipStatus FirstTransactionDate  LastTransactionDate  \
# 0   301002470            Aktif  2015-09-18 14:35:04  2023-10-26 10:47:00
# 1   301002583            Pasif  2014-09-25 10:08:52  2020-12-23 12:28:28
# 2   301003354            Aktif  2022-11-21 18:05:00  2023-10-26 16:59:00
# 3   301006906            Pasif  2016-01-29 11:00:43  2022-09-12 18:30:00
# 4   301009366            Pasif  2019-06-27 17:31:14  2022-09-19 18:01:00
# 5   301009412            Pasif  2016-08-26 11:00:35  2023-10-03 17:56:28
# 6   301009682            Aktif  2016-05-19 10:29:01  2023-10-26 16:39:00
# 7   301010389            Aktif  2016-06-15 15:12:25  2020-05-10 11:09:14
# 8   301012873            Aktif  2018-12-07 12:52:00  2023-10-26 15:06:00
# 9   301014561            Aktif  2017-08-10 14:22:03  2023-10-26 16:55:00
# 10  301015331            Aktif  2017-02-09 11:21:52  2023-10-26 13:45:18
# 11  301018129            Pasif  2018-09-15 15:53:45  2018-09-15 15:53:45
# 12  301019658            Pasif  2017-05-26 17:37:46  2023-09-06 20:44:00
# 13  301020464            Aktif  2022-06-11 10:39:00  2023-10-26 16:56:00
# 14  301021277            Aktif  2017-07-24 14:19:13  2023-10-26 14:36:59
# 15  301023021            Aktif  2017-11-07 16:48:45  2023-10-26 16:58:03
# 16  301024520            Aktif  2017-12-18 17:52:53  2023-10-26 14:27:00
# 17  301024729            Pasif  2019-05-17 16:30:00  2023-07-10 08:56:00
# 18  301025172            Aktif  2018-01-11 08:37:44  2023-10-26 16:46:00
# 19  301025251            Pasif  2018-05-02 15:16:56  2018-07-24 11:03:37
# 20  301025608            Aktif  2018-01-29 16:12:25  2023-10-26 16:50:00
# 21  301026102            Aktif  2018-02-22 20:16:36  2023-10-26 16:21:00
# 22  301026135            Aktif  2018-08-30 17:47:27  2023-10-26 16:42:00
# 23  301026224            Aktif  2018-02-20 19:35:09  2023-10-26 15:17:59
# 24  301026287            Aktif  2018-03-06 19:02:42  2023-10-26 16:53:00
# 25  301026648            Pasif  2018-03-13 17:58:26  2021-04-30 17:08:00
# 26  301026840            Pasif  2018-03-22 14:46:46  2023-06-08 18:01:00
# 27  301026958            Aktif  2019-07-24 16:33:59  2021-05-04 21:19:38
# 28  301027114            Pasif  2018-05-05 20:10:08  2023-07-18 17:22:00
# 29  301029464            Pasif  2018-08-17 19:15:49  2022-11-14 11:07:00
# 30  301029860            Pasif  2018-09-14 08:26:00  2019-11-28 14:26:47
# 31  301030119            Aktif  2018-10-20 14:48:26  2023-10-26 14:47:00
# 32  301030448            Pasif  2018-10-24 16:11:46  2023-08-24 21:57:00
# 33  301031149            Pasif  2018-11-19 14:12:00  2021-05-19 11:54:00
# 34  301031272            Aktif  2018-11-21 14:13:00  2023-10-26 14:38:00
# 35  301031339            Aktif  2018-11-26 17:46:00  2023-09-01 05:54:00
# 36  301032425            Aktif  2018-12-29 14:51:00  2023-10-24 21:22:00
# 37  301032496            Pasif  2018-12-28 16:19:46  2020-11-25 22:10:00
# 38  301033049            Pasif  2019-02-01 16:40:00  2023-06-09 22:21:00
#
#     DaysSinceLastTransaction ChurnStatus  RecencyScore  FrequencyScore  \
# 0                          0    Retained             3               3
# 1                       1037     Churned             1               1
# 2                          0    Retained             3               4
# 3                        408     Churned             1               4
# 4                        401     Churned             2               3
# 5                         22     At Risk             3               1
# 6                          0    Retained             3               1
# 7                       1264     Churned             1               2
# 8                          0    Retained             3               3
# 9                          0    Retained             3               3
# 10                         0    Retained             3               3
# 11                      1867     Churned             1               1
# 12                        49     At Risk             2               3
# 13                         0    Retained             3               2
# 14                         0    Retained             3               1
# 15                         0    Retained             3               1
# 16                         0    Retained             3               2
# 17                       108     Churned             2               4
# 18                         0    Retained             3               4
# 19                      1920     Churned             1               1
# 20                         0    Retained             3               4
# 21                         0    Retained             3               4
# 22                         0    Retained             3               1
# 23                         0    Retained             3               1
# 24                         0    Retained             3               3
# 25                       908     Churned             1               2
# 26                       139     Churned             2               4
# 27                       904     Churned             1               1
# 28                        99     Churned             2               2
# 29                       346     Churned             2               2
# 30                      1428     Churned             1               2
# 31                         0    Retained             3               2
# 32                        62     At Risk             2               2
# 33                       890     Churned             1               3
# 34                         0    Retained             3               4
# 35                        55     At Risk             2               3
# 36                         1    Retained             3               4
# 37                      1064     Churned             1               2
# 38                       138     Churned             2               4
#
#     MonetaryScore  RFMScore   Segment  \
# 0               4        10  Platinum
# 1               1         3     Bronz
# 2               3        10  Platinum
# 3               3         8     Altın
# 4               2         7     Gümüş
# 5               1         5     Gümüş
# 6               4         8     Altın
# 7               1         4     Bronz
# 8               2         8     Altın
# 9               3         9     Altın
# 10              4        10  Platinum
# 11              1         3     Bronz
# 12              4         9     Altın
# 13              3         8     Altın
# 14              4         8     Altın
# 15              4         8     Altın
# 16              1         6     Gümüş
# 17              2         8     Altın
# 18              3        10  Platinum
# 19              1         3     Bronz
# 20              4        11  Platinum
# 21              2         9     Altın
# 22              3         7     Gümüş
# 23              4         8     Altın
# 24              2         8     Altın
# 25              2         5     Gümüş
# 26              3         9     Altın
# 27              1         3     Bronz
# 28              2         6     Gümüş
# 29              1         5     Gümüş
# 30              2         5     Gümüş
# 31              3         8     Altın
# 32              1         5     Gümüş
# 33              1         5     Gümüş
# 34              4        11  Platinum
# 35              3         8     Altın
# 36              4        11  Platinum
# 37              2         5     Gümüş
# 38              2         8     Altın
#
#                                    SegmentDescription
# 0   Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 1   Düşük değerli müşteri. Ortalamanın çok altında...
# 2   Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 3   Orta değerli müşteri. Ortalamanın üzerinde sık...
# 4   Düşük-orta değerli müşteri. Ortalamanın altınd...
# 5   Düşük-orta değerli müşteri. Ortalamanın altınd...
# 6   Orta değerli müşteri. Ortalamanın üzerinde sık...
# 7   Düşük değerli müşteri. Ortalamanın çok altında...
# 8   Orta değerli müşteri. Ortalamanın üzerinde sık...
# 9   Orta değerli müşteri. Ortalamanın üzerinde sık...
# 10  Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 11  Düşük değerli müşteri. Ortalamanın çok altında...
# 12  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 13  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 14  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 15  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 16  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 17  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 18  Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 19  Düşük değerli müşteri. Ortalamanın çok altında...
# 20  Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 21  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 22  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 23  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 24  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 25  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 26  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 27  Düşük değerli müşteri. Ortalamanın çok altında...
# 28  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 29  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 30  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 31  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 32  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 33  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 34  Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 35  Orta değerli müşteri. Ortalamanın üzerinde sık...
# 36  Yüksek değerli müşteri. Ortalamanın çok üzerin...
# 37  Düşük-orta değerli müşteri. Ortalamanın altınd...
# 38  Orta değerli müşteri. Ortalamanın üzerinde sık...

# %% [markdown]
# ---
# ### Data Preprocessing and Enrichment with Socioeconomic Metrics via Scraping 🌐📈
# ---

# %%
import pandas as pd
from datetime import timedelta
import json

class DataProcessor:
    def __init__(self, mapping_file='data/city_mapping.json', data_file='data/formatted_data.json'):
        self.city_mapping = self.load_json(mapping_file)
        self.socioeconomic_data = self.load_json(data_file)

    @staticmethod
    def load_json(file_path):
        with open(file_path, 'r') as f:
            return json.load(f)

    def add_socioeconomic_info(self, df, city_column):
        df['CitySocioeconomicInfo'] = df[city_column].apply(lambda x: self.socioeconomic_data.get(x, None))
        return df

    @staticmethod
    def map_column(df, column_name, mapping):
        df[column_name] = df[column_name].map(mapping).fillna(df[column_name])
        return df

    @staticmethod
    def group_and_aggregate(df, group_by_col, agg_instructions):
        return df.groupby(group_by_col).agg(agg_instructions)

    @staticmethod
    def get_customer_status(df):
        transaction_date_col = 'TransactionDate'
        transaction_amount_col = 'TransactionAmount'
        customer_id_col = 'id'
        latest_date = df[transaction_date_col].max()

        time_frames = list(range(1, 366))

        def calculate_transactions_stats(df, days, latest_date):
            past_date = latest_date - timedelta(days=days)
            filtered_df = df[(df[transaction_date_col] >= past_date) & (df[transaction_date_col] <= latest_date)]
            transactions_count = filtered_df.groupby(customer_id_col).size().astype('int').to_dict()
            transactions_amount = filtered_df.groupby(customer_id_col)[transaction_amount_col].sum().to_dict()
            return transactions_count, transactions_amount

        json_structures = pd.DataFrame(columns=['TransactionDetails'], index=df[customer_id_col].unique())

        for days in time_frames:
            transactions_count, transactions_amount = calculate_transactions_stats(df, days, latest_date)
            for customer_id in json_structures.index:
                customer_data = json_structures.at[customer_id, 'TransactionDetails']
                customer_data = json.loads(customer_data) if pd.notnull(customer_data) else {}
                customer_data[f'Last{days}Days_TransactionCount'] = transactions_count.get(customer_id, 0)
                customer_data[f'Last{days}Days_TransactionAmount'] = transactions_amount.get(customer_id, 0.0)
                json_structures.at[customer_id, 'TransactionDetails'] = json.dumps(customer_data)

        unique_records = df.groupby(customer_id_col).agg({
            'BusinessType': 'first',
            'MembershipActivationDate': 'first'
        }).reset_index()

        unique_records = unique_records.join(json_structures, on=customer_id_col)

        return unique_records

    def process_data(self, df):
        df.rename(columns={
            'IslemTarih': 'TransactionDate',
            'IslemTutar': 'TransactionAmount',
            'IsyeriTipi': 'BusinessType',
            'UyeAktivasyonTarih': 'MembershipActivationDate',
            'Sehir': 'City',  
            'Tercih': 'PreferredSolution'
        }, inplace=True)

        df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

        df = self.map_column(df, 'City', self.city_mapping)

        new_df_grouped = self.group_and_aggregate(df, 'id', {
            'City': 'first',
            'PreferredSolution': lambda x: list(set(x))
        })
        
        new_df_grouped['PreferredSolution'] = new_df_grouped['PreferredSolution'].apply(lambda x: x[0] if len(x) == 1 else x)

        result_df = self.get_customer_status(df)

        final_df = result_df.merge(new_df_grouped, on='id', how='left')
        
        return self.add_socioeconomic_info(final_df, 'City')

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning) 

df = pd.read_csv('data/new_dataframe.csv', low_memory=False)
df.drop('Unnamed: 0', axis=1, inplace=True)

processor = DataProcessor()
processed_df = processor.process_data(df)
processed_df
# Out:
#            id   BusinessType MembershipActivationDate  \
# 0   301002470   Tüzel Şirket      2015-09-08 15:08:23
# 1   301002583       Bireysel      2016-09-20 12:14:43
# 2   301003354   Tüzel Şirket      2014-09-10 12:54:01
# 3   301006906  Şahıs Şirketi      2020-09-19 14:13:33
# 4   301009366  Şahıs Şirketi      2019-07-19 14:53:05
# 5   301009412       Bireysel      2018-06-28 15:14:36
# 6   301009682   Tüzel Şirket      2016-05-12 15:48:12
# 7   301010389   Tüzel Şirket      2016-06-15 12:07:17
# 8   301012873   Tüzel Şirket      2022-08-16 08:48:29
# 9   301014561   Tüzel Şirket      2016-12-27 19:42:50
# 10  301015331   Tüzel Şirket      2017-01-25 12:06:22
# 11  301018129  Şahıs Şirketi      2017-04-14 09:55:36
# 12  301019658  Şahıs Şirketi      2021-06-02 11:50:10
# 13  301020464   Tüzel Şirket      2022-05-27 10:56:38
# 14  301021277   Tüzel Şirket      2017-07-19 10:24:28
# 15  301023021   Tüzel Şirket      2017-10-02 16:50:43
# 16  301024520  Şahıs Şirketi      2017-12-14 10:04:15
# 17  301024729   Tüzel Şirket      2022-12-10 15:38:46
# 18  301025172  Şahıs Şirketi      2018-01-10 15:40:18
# 19  301025251       Bireysel      2018-08-14 11:06:24
# 20  301025608  Şahıs Şirketi      2018-01-26 15:08:50
# 21  301026102  Şahıs Şirketi      2018-02-21 18:36:14
# 22  301026135  Şahıs Şirketi      2018-02-16 14:45:17
# 23  301026224  Şahıs Şirketi      2018-02-20 18:51:03
# 24  301026287  Şahıs Şirketi      2018-02-28 17:59:27
# 25  301026648  Şahıs Şirketi      2018-03-13 17:40:36
# 26  301026840  Şahıs Şirketi      2018-03-22 13:33:45
# 27  301026958  Şahıs Şirketi      2019-03-04 13:38:20
# 28  301027114  Şahıs Şirketi      2018-05-03 16:01:49
# 29  301029464  Şahıs Şirketi      2020-02-20 14:07:37
# 30  301029860   Tüzel Şirket      2018-09-14 10:19:24
# 31  301030119  Şahıs Şirketi      2018-10-20 13:49:35
# 32  301030448   Tüzel Şirket      2018-10-23 19:05:38
# 33  301031149  Şahıs Şirketi      2018-11-19 11:18:13
# 34  301031272  Şahıs Şirketi      2018-11-21 13:29:14
# 35  301031339   Tüzel Şirket      2018-11-24 17:41:17
# 36  301032425  Şahıs Şirketi      2018-12-28 15:13:16
# 37  301032496   Tüzel Şirket      2018-12-28 14:50:22
# 38  301033049  Şahıs Şirketi      2019-01-31 15:47:21
#
#                                    TransactionDetails                   City  \
# 0   {"Last1Days_TransactionCount": 2, "Last1Days_T...         Samsun/Ilkadim
# 1   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Beşiktaş
# 2   {"Last1Days_TransactionCount": 100, "Last1Days...    Istanbul/Bayrampaşa
# 3   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ümraniye
# 4   {"Last1Days_TransactionCount": 0, "Last1Days_T...            Manisa/Soma
# 5   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Beşiktaş
# 6   {"Last1Days_TransactionCount": 21, "Last1Days_...             Izmir/Buca
# 7   {"Last1Days_TransactionCount": 0, "Last1Days_T...        Aksaray/Ortaköy
# 8   {"Last1Days_TransactionCount": 2, "Last1Days_T...          Izmir/Bornova
# 9   {"Last1Days_TransactionCount": 50, "Last1Days_...          Antalya/Kepez
# 10  {"Last1Days_TransactionCount": 2, "Last1Days_T...  Istanbul/Bahçelievler
# 11  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Istanbul/Kartal
# 12  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ümraniye
# 13  {"Last1Days_TransactionCount": 65, "Last1Days_...        Bursa/Osmangazi
# 14  {"Last1Days_TransactionCount": 9, "Last1Days_T...     Istanbul/Kağithane
# 15  {"Last1Days_TransactionCount": 23, "Last1Days_...     Istanbul/Kağithane
# 16  {"Last1Days_TransactionCount": 18, "Last1Days_...         Istanbul/Fatih
# 17  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Güngören
# 18  {"Last1Days_TransactionCount": 36, "Last1Days_...         Istanbul/Fatih
# 19  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Kocaeli/Derince
# 20  {"Last1Days_TransactionCount": 135, "Last1Days...  Istanbul/Küçükçekmece
# 21  {"Last1Days_TransactionCount": 41, "Last1Days_...  Istanbul/Küçükçekmece
# 22  {"Last1Days_TransactionCount": 19, "Last1Days_...           Samsun/Canik
# 23  {"Last1Days_TransactionCount": 6, "Last1Days_T...         Ankara/Elmadağ
# 24  {"Last1Days_TransactionCount": 38, "Last1Days_...  Istanbul/Küçükçekmece
# 25  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 26  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 27  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ataşehir
# 28  {"Last1Days_TransactionCount": 0, "Last1Days_T...         Istanbul/Fatih
# 29  {"Last1Days_TransactionCount": 0, "Last1Days_T...    Istanbul/Sancaktepe
# 30  {"Last1Days_TransactionCount": 0, "Last1Days_T...         Istanbul/Şişli
# 31  {"Last1Days_TransactionCount": 17, "Last1Days_...   Eskişehir/Odunpazarı
# 32  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 33  {"Last1Days_TransactionCount": 0, "Last1Days_T...          Izmir/Bornova
# 34  {"Last1Days_TransactionCount": 55, "Last1Days_...        Istanbul/Kartal
# 35  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Esenyurt
# 36  {"Last1Days_TransactionCount": 0, "Last1Days_T...       Giresun/Bulancak
# 37  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Ankara/Altındağ
# 38  {"Last1Days_TransactionCount": 0, "Last1Days_T...   Gaziantep/Şehitkamil
#
#            PreferredSolution  \
# 0            [CeptePos, ÖKC]
# 1                   CeptePos
# 2                        ÖKC
# 3            [CeptePos, ÖKC]
# 4            [CeptePos, ÖKC]
# 5                   CeptePos
# 6            [CeptePos, ÖKC]
# 7                   CeptePos
# 8                        ÖKC
# 9            [CeptePos, ÖKC]
# 10                  CeptePos
# 11                       ÖKC
# 12           [CeptePos, ÖKC]
# 13                       ÖKC
# 14                  CeptePos
# 15                  CeptePos
# 16                       ÖKC
# 17                       ÖKC
# 18                       ÖKC
# 19                  CeptePos
# 20                       ÖKC
# 21                       ÖKC
# 22                       ÖKC
# 23  [SadePos, CeptePos, ÖKC]
# 24                       ÖKC
# 25                       ÖKC
# 26                       ÖKC
# 27                  CeptePos
# 28                       ÖKC
# 29            [SadePos, ÖKC]
# 30                       ÖKC
# 31                       ÖKC
# 32                       ÖKC
# 33                       ÖKC
# 34                       ÖKC
# 35                       ÖKC
# 36            [SadePos, ÖKC]
# 37           [CeptePos, ÖKC]
# 38                       ÖKC
#
#                                 CitySocioeconomicInfo
# 0   {'YASLI/GENC ORANI': {'Genc': 50.0, 'Orta': 21...
# 1   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 2   {'Yaşlı/Genç Oranı': {'Genç': 65.0, 'Orta': 4....
# 3   {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 4   {'YAŞLI/GENÇ ORANI': {'Genç': 16.0, 'Orta': 31...
# 5   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 6   {'Yaşlı/Genç Oranı': {'Genç': 20.0, 'Orta': 53...
# 7   {'YAŞLI/GENÇ ORANI': {'Genç': 949.0, 'Orta': 9...
# 8   {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 9   {'Yaşlı/Genç Oranı': {'Genç': 68.0, 'Orta': 25...
# 10  {'Yaşlı/Genç Oranı': {'Genç': 18.0, 'Orta': 51...
# 11  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 12  {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 13  {'Yaşlı/Genç Oranı': {'Genç': 52.0, 'Orta': 29...
# 14  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 15  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 16  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 17  {'YASLI/GENC ORANI': {'Genc': 55.0, 'Orta': 28...
# 18  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 19  {'YASLI/GENC ORANI': {'Genç': 52.0, 'Orta': 34...
# 20  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 21  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 22  {'YAŞLI/GENÇ ORANI': {'Genç': 61.0, 'Orta': 12...
# 23  {'Yaş Grupları': {'Genç': 14.0, 'Orta': 54.0, ...
# 24  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 25  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 26  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 27  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 33...
# 28  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 29  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 8....
# 30  {'Yaşlı/Genç Oranı': {'Genç': 23.0, 'Orta': 57...
# 31  {'YASLI/GENC ORANI': {'Genc': 52.0, 'Orta': 29...
# 32  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 33  {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 34  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 35  {'yasli_genç_orani': {'genç': 96.0, 'orta': 94...
# 36  {'YASLI/GENC ORANI': {'Genç': 49.0, 'Orta': 20...
# 37  {'YASLI/GENC ORANI': {'Genc': 30.0, 'Orta': ''...
# 38  {'YASLI/GENC ORANI': {'Genc': 945.0, 'Orta': 6...

# %% [markdown]
# # Merge dataframes

# %%
merged_df = pd.merge(result_df, processed_df, on='id', how='outer')
merged_df
# Out:
#            id MembershipStatus FirstTransactionDate  LastTransactionDate  \
# 0   301002470            Aktif  2015-09-18 14:35:04  2023-10-26 10:47:00
# 1   301002583            Pasif  2014-09-25 10:08:52  2020-12-23 12:28:28
# 2   301003354            Aktif  2022-11-21 18:05:00  2023-10-26 16:59:00
# 3   301006906            Pasif  2016-01-29 11:00:43  2022-09-12 18:30:00
# 4   301009366            Pasif  2019-06-27 17:31:14  2022-09-19 18:01:00
# 5   301009412            Pasif  2016-08-26 11:00:35  2023-10-03 17:56:28
# 6   301009682            Aktif  2016-05-19 10:29:01  2023-10-26 16:39:00
# 7   301010389            Aktif  2016-06-15 15:12:25  2020-05-10 11:09:14
# 8   301012873            Aktif  2018-12-07 12:52:00  2023-10-26 15:06:00
# 9   301014561            Aktif  2017-08-10 14:22:03  2023-10-26 16:55:00
# 10  301015331            Aktif  2017-02-09 11:21:52  2023-10-26 13:45:18
# 11  301018129            Pasif  2018-09-15 15:53:45  2018-09-15 15:53:45
# 12  301019658            Pasif  2017-05-26 17:37:46  2023-09-06 20:44:00
# 13  301020464            Aktif  2022-06-11 10:39:00  2023-10-26 16:56:00
# 14  301021277            Aktif  2017-07-24 14:19:13  2023-10-26 14:36:59
# 15  301023021            Aktif  2017-11-07 16:48:45  2023-10-26 16:58:03
# 16  301024520            Aktif  2017-12-18 17:52:53  2023-10-26 14:27:00
# 17  301024729            Pasif  2019-05-17 16:30:00  2023-07-10 08:56:00
# 18  301025172            Aktif  2018-01-11 08:37:44  2023-10-26 16:46:00
# 19  301025251            Pasif  2018-05-02 15:16:56  2018-07-24 11:03:37
# 20  301025608            Aktif  2018-01-29 16:12:25  2023-10-26 16:50:00
# 21  301026102            Aktif  2018-02-22 20:16:36  2023-10-26 16:21:00
# 22  301026135            Aktif  2018-08-30 17:47:27  2023-10-26 16:42:00
# 23  301026224            Aktif  2018-02-20 19:35:09  2023-10-26 15:17:59
# 24  301026287            Aktif  2018-03-06 19:02:42  2023-10-26 16:53:00
# 25  301026648            Pasif  2018-03-13 17:58:26  2021-04-30 17:08:00
# 26  301026840            Pasif  2018-03-22 14:46:46  2023-06-08 18:01:00
# 27  301026958            Aktif  2019-07-24 16:33:59  2021-05-04 21:19:38
# 28  301027114            Pasif  2018-05-05 20:10:08  2023-07-18 17:22:00
# 29  301029464            Pasif  2018-08-17 19:15:49  2022-11-14 11:07:00
# 30  301029860            Pasif  2018-09-14 08:26:00  2019-11-28 14:26:47
# 31  301030119            Aktif  2018-10-20 14:48:26  2023-10-26 14:47:00
# 32  301030448            Pasif  2018-10-24 16:11:46  2023-08-24 21:57:00
# 33  301031149            Pasif  2018-11-19 14:12:00  2021-05-19 11:54:00
# 34  301031272            Aktif  2018-11-21 14:13:00  2023-10-26 14:38:00
# 35  301031339            Aktif  2018-11-26 17:46:00  2023-09-01 05:54:00
# 36  301032425            Aktif  2018-12-29 14:51:00  2023-10-24 21:22:00
# 37  301032496            Pasif  2018-12-28 16:19:46  2020-11-25 22:10:00
# 38  301033049            Pasif  2019-02-01 16:40:00  2023-06-09 22:21:00
#
#     DaysSinceLastTransaction ChurnStatus  RecencyScore  FrequencyScore  \
# 0                          0    Retained             3               3
# 1                       1037     Churned             1               1
# 2                          0    Retained             3               4
# 3                        408     Churned             1               4
# 4                        401     Churned             2               3
# 5                         22     At Risk             3               1
# 6                          0    Retained             3               1
# 7                       1264     Churned             1               2
# 8                          0    Retained             3               3
# 9                          0    Retained             3               3
# 10                         0    Retained             3               3
# 11                      1867     Churned             1               1
# 12                        49     At Risk             2               3
# 13                         0    Retained             3               2
# 14                         0    Retained             3               1
# 15                         0    Retained             3               1
# 16                         0    Retained             3               2
# 17                       108     Churned             2               4
# 18                         0    Retained             3               4
# 19                      1920     Churned             1               1
# 20                         0    Retained             3               4
# 21                         0    Retained             3               4
# 22                         0    Retained             3               1
# 23                         0    Retained             3               1
# 24                         0    Retained             3               3
# 25                       908     Churned             1               2
# 26                       139     Churned             2               4
# 27                       904     Churned             1               1
# 28                        99     Churned             2               2
# 29                       346     Churned             2               2
# 30                      1428     Churned             1               2
# 31                         0    Retained             3               2
# 32                        62     At Risk             2               2
# 33                       890     Churned             1               3
# 34                         0    Retained             3               4
# 35                        55     At Risk             2               3
# 36                         1    Retained             3               4
# 37                      1064     Churned             1               2
# 38                       138     Churned             2               4
#
#     MonetaryScore  RFMScore   Segment  \
# 0               4        10  Platinum
# 1               1         3     Bronz
# 2               3        10  Platinum
# 3               3         8     Altın
# 4               2         7     Gümüş
# 5               1         5     Gümüş
# 6               4         8     Altın
# 7               1         4     Bronz
# 8               2         8     Altın
# 9               3         9     Altın
# 10              4        10  Platinum
# 11              1         3     Bronz
# 12              4         9     Altın
# 13              3         8     Altın
# 14              4         8     Altın
# 15              4         8     Altın
# 16              1         6     Gümüş
# 17              2         8     Altın
# 18              3        10  Platinum
# 19              1         3     Bronz
# 20              4        11  Platinum
# 21              2         9     Altın
# 22              3         7     Gümüş
# 23              4         8     Altın
# 24              2         8     Altın
# 25              2         5     Gümüş
# 26              3         9     Altın
# 27              1         3     Bronz
# 28              2         6     Gümüş
# 29              1         5     Gümüş
# 30              2         5     Gümüş
# 31              3         8     Altın
# 32              1         5     Gümüş
# 33              1         5     Gümüş
# 34              4        11  Platinum
# 35              3         8     Altın
# 36              4        11  Platinum
# 37              2         5     Gümüş
# 38              2         8     Altın
#
#                                    SegmentDescription   BusinessType  \
# 0   Yüksek değerli müşteri. Ortalamanın çok üzerin...   Tüzel Şirket
# 1   Düşük değerli müşteri. Ortalamanın çok altında...       Bireysel
# 2   Yüksek değerli müşteri. Ortalamanın çok üzerin...   Tüzel Şirket
# 3   Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 4   Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 5   Düşük-orta değerli müşteri. Ortalamanın altınd...       Bireysel
# 6   Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 7   Düşük değerli müşteri. Ortalamanın çok altında...   Tüzel Şirket
# 8   Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 9   Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 10  Yüksek değerli müşteri. Ortalamanın çok üzerin...   Tüzel Şirket
# 11  Düşük değerli müşteri. Ortalamanın çok altında...  Şahıs Şirketi
# 12  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 13  Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 14  Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 15  Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 16  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 17  Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 18  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Şahıs Şirketi
# 19  Düşük değerli müşteri. Ortalamanın çok altında...       Bireysel
# 20  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Şahıs Şirketi
# 21  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 22  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 23  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 24  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 25  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 26  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 27  Düşük değerli müşteri. Ortalamanın çok altında...  Şahıs Şirketi
# 28  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 29  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 30  Düşük-orta değerli müşteri. Ortalamanın altınd...   Tüzel Şirket
# 31  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
# 32  Düşük-orta değerli müşteri. Ortalamanın altınd...   Tüzel Şirket
# 33  Düşük-orta değerli müşteri. Ortalamanın altınd...  Şahıs Şirketi
# 34  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Şahıs Şirketi
# 35  Orta değerli müşteri. Ortalamanın üzerinde sık...   Tüzel Şirket
# 36  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Şahıs Şirketi
# 37  Düşük-orta değerli müşteri. Ortalamanın altınd...   Tüzel Şirket
# 38  Orta değerli müşteri. Ortalamanın üzerinde sık...  Şahıs Şirketi
#
#    MembershipActivationDate  \
# 0       2015-09-08 15:08:23
# 1       2016-09-20 12:14:43
# 2       2014-09-10 12:54:01
# 3       2020-09-19 14:13:33
# 4       2019-07-19 14:53:05
# 5       2018-06-28 15:14:36
# 6       2016-05-12 15:48:12
# 7       2016-06-15 12:07:17
# 8       2022-08-16 08:48:29
# 9       2016-12-27 19:42:50
# 10      2017-01-25 12:06:22
# 11      2017-04-14 09:55:36
# 12      2021-06-02 11:50:10
# 13      2022-05-27 10:56:38
# 14      2017-07-19 10:24:28
# 15      2017-10-02 16:50:43
# 16      2017-12-14 10:04:15
# 17      2022-12-10 15:38:46
# 18      2018-01-10 15:40:18
# 19      2018-08-14 11:06:24
# 20      2018-01-26 15:08:50
# 21      2018-02-21 18:36:14
# 22      2018-02-16 14:45:17
# 23      2018-02-20 18:51:03
# 24      2018-02-28 17:59:27
# 25      2018-03-13 17:40:36
# 26      2018-03-22 13:33:45
# 27      2019-03-04 13:38:20
# 28      2018-05-03 16:01:49
# 29      2020-02-20 14:07:37
# 30      2018-09-14 10:19:24
# 31      2018-10-20 13:49:35
# 32      2018-10-23 19:05:38
# 33      2018-11-19 11:18:13
# 34      2018-11-21 13:29:14
# 35      2018-11-24 17:41:17
# 36      2018-12-28 15:13:16
# 37      2018-12-28 14:50:22
# 38      2019-01-31 15:47:21
#
#                                    TransactionDetails                   City  \
# 0   {"Last1Days_TransactionCount": 2, "Last1Days_T...         Samsun/Ilkadim
# 1   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Beşiktaş
# 2   {"Last1Days_TransactionCount": 100, "Last1Days...    Istanbul/Bayrampaşa
# 3   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ümraniye
# 4   {"Last1Days_TransactionCount": 0, "Last1Days_T...            Manisa/Soma
# 5   {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Beşiktaş
# 6   {"Last1Days_TransactionCount": 21, "Last1Days_...             Izmir/Buca
# 7   {"Last1Days_TransactionCount": 0, "Last1Days_T...        Aksaray/Ortaköy
# 8   {"Last1Days_TransactionCount": 2, "Last1Days_T...          Izmir/Bornova
# 9   {"Last1Days_TransactionCount": 50, "Last1Days_...          Antalya/Kepez
# 10  {"Last1Days_TransactionCount": 2, "Last1Days_T...  Istanbul/Bahçelievler
# 11  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Istanbul/Kartal
# 12  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ümraniye
# 13  {"Last1Days_TransactionCount": 65, "Last1Days_...        Bursa/Osmangazi
# 14  {"Last1Days_TransactionCount": 9, "Last1Days_T...     Istanbul/Kağithane
# 15  {"Last1Days_TransactionCount": 23, "Last1Days_...     Istanbul/Kağithane
# 16  {"Last1Days_TransactionCount": 18, "Last1Days_...         Istanbul/Fatih
# 17  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Güngören
# 18  {"Last1Days_TransactionCount": 36, "Last1Days_...         Istanbul/Fatih
# 19  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Kocaeli/Derince
# 20  {"Last1Days_TransactionCount": 135, "Last1Days...  Istanbul/Küçükçekmece
# 21  {"Last1Days_TransactionCount": 41, "Last1Days_...  Istanbul/Küçükçekmece
# 22  {"Last1Days_TransactionCount": 19, "Last1Days_...           Samsun/Canik
# 23  {"Last1Days_TransactionCount": 6, "Last1Days_T...         Ankara/Elmadağ
# 24  {"Last1Days_TransactionCount": 38, "Last1Days_...  Istanbul/Küçükçekmece
# 25  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 26  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 27  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Ataşehir
# 28  {"Last1Days_TransactionCount": 0, "Last1Days_T...         Istanbul/Fatih
# 29  {"Last1Days_TransactionCount": 0, "Last1Days_T...    Istanbul/Sancaktepe
# 30  {"Last1Days_TransactionCount": 0, "Last1Days_T...         Istanbul/Şişli
# 31  {"Last1Days_TransactionCount": 17, "Last1Days_...   Eskişehir/Odunpazarı
# 32  {"Last1Days_TransactionCount": 0, "Last1Days_T...  Istanbul/Küçükçekmece
# 33  {"Last1Days_TransactionCount": 0, "Last1Days_T...          Izmir/Bornova
# 34  {"Last1Days_TransactionCount": 55, "Last1Days_...        Istanbul/Kartal
# 35  {"Last1Days_TransactionCount": 0, "Last1Days_T...      Istanbul/Esenyurt
# 36  {"Last1Days_TransactionCount": 0, "Last1Days_T...       Giresun/Bulancak
# 37  {"Last1Days_TransactionCount": 0, "Last1Days_T...        Ankara/Altındağ
# 38  {"Last1Days_TransactionCount": 0, "Last1Days_T...   Gaziantep/Şehitkamil
#
#            PreferredSolution  \
# 0            [CeptePos, ÖKC]
# 1                   CeptePos
# 2                        ÖKC
# 3            [CeptePos, ÖKC]
# 4            [CeptePos, ÖKC]
# 5                   CeptePos
# 6            [CeptePos, ÖKC]
# 7                   CeptePos
# 8                        ÖKC
# 9            [CeptePos, ÖKC]
# 10                  CeptePos
# 11                       ÖKC
# 12           [CeptePos, ÖKC]
# 13                       ÖKC
# 14                  CeptePos
# 15                  CeptePos
# 16                       ÖKC
# 17                       ÖKC
# 18                       ÖKC
# 19                  CeptePos
# 20                       ÖKC
# 21                       ÖKC
# 22                       ÖKC
# 23  [SadePos, CeptePos, ÖKC]
# 24                       ÖKC
# 25                       ÖKC
# 26                       ÖKC
# 27                  CeptePos
# 28                       ÖKC
# 29            [SadePos, ÖKC]
# 30                       ÖKC
# 31                       ÖKC
# 32                       ÖKC
# 33                       ÖKC
# 34                       ÖKC
# 35                       ÖKC
# 36            [SadePos, ÖKC]
# 37           [CeptePos, ÖKC]
# 38                       ÖKC
#
#                                 CitySocioeconomicInfo
# 0   {'YASLI/GENC ORANI': {'Genc': 50.0, 'Orta': 21...
# 1   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 2   {'Yaşlı/Genç Oranı': {'Genç': 65.0, 'Orta': 4....
# 3   {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 4   {'YAŞLI/GENÇ ORANI': {'Genç': 16.0, 'Orta': 31...
# 5   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 6   {'Yaşlı/Genç Oranı': {'Genç': 20.0, 'Orta': 53...
# 7   {'YAŞLI/GENÇ ORANI': {'Genç': 949.0, 'Orta': 9...
# 8   {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 9   {'Yaşlı/Genç Oranı': {'Genç': 68.0, 'Orta': 25...
# 10  {'Yaşlı/Genç Oranı': {'Genç': 18.0, 'Orta': 51...
# 11  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 12  {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 13  {'Yaşlı/Genç Oranı': {'Genç': 52.0, 'Orta': 29...
# 14  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 15  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 16  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 17  {'YASLI/GENC ORANI': {'Genc': 55.0, 'Orta': 28...
# 18  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 19  {'YASLI/GENC ORANI': {'Genç': 52.0, 'Orta': 34...
# 20  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 21  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 22  {'YAŞLI/GENÇ ORANI': {'Genç': 61.0, 'Orta': 12...
# 23  {'Yaş Grupları': {'Genç': 14.0, 'Orta': 54.0, ...
# 24  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 25  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 26  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 27  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 33...
# 28  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 29  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 8....
# 30  {'Yaşlı/Genç Oranı': {'Genç': 23.0, 'Orta': 57...
# 31  {'YASLI/GENC ORANI': {'Genc': 52.0, 'Orta': 29...
# 32  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 33  {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 34  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 35  {'yasli_genç_orani': {'genç': 96.0, 'orta': 94...
# 36  {'YASLI/GENC ORANI': {'Genç': 49.0, 'Orta': 20...
# 37  {'YASLI/GENC ORANI': {'Genc': 30.0, 'Orta': ''...
# 38  {'YASLI/GENC ORANI': {'Genc': 945.0, 'Orta': 6...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        39 non-null     int64
#  1   MembershipStatus          39 non-null     object
#  2   FirstTransactionDate      39 non-null     object
#  3   LastTransactionDate       39 non-null     object
#  4   DaysSinceLastTransaction  39 non-null     int64
#  5   ChurnStatus               39 non-null     object
#  6   RecencyScore              39 non-null     int64
#  7   FrequencyScore            39 non-null     int64
#  8   MonetaryScore             39 non-null     int64
#  9   RFMScore                  39 non-null     int64
#  10  Segment                   39 non-null     object
#  11  SegmentDescription        39 non-null     object
#  12  BusinessType              39 non-null     object
#  13  MembershipActivationDate  39 non-null     object
#  14  TransactionDetails        39 non-null     object
#  15  City                      39 non-null     object
#  16  PreferredSolution         39 non-null     object
#  17  CitySocioeconomicInfo     39 non-null     object
# dtypes: int64(6), object(12)
# memory usage: 5.6+ KB

# %%
import pandas as pd
import json
import os

for index, row in merged_df.iterrows():
    row_dict = row.to_dict()
    
    json_object = json.dumps(row_dict, indent=4, ensure_ascii=False)
    
    if not os.path.exists('jsons'):
        os.makedirs('jsons')
    
    with open(f'jsons/{row_dict["id"]}.json', 'w', encoding='utf-8') as json_file:
        json_file.write(json_object)

# %%
merged_df.to_csv('data/hackathon_final_csv.csv', index=False)
