# %%
import pandas as pd
import json

class DataProcessor:
    def __init__(self):
        self.city_mapping_corrected = {
            'İLKADIM/SAMSUN': 'Samsun/Ilkadim',
            'BEŞIKTAŞ/İSTANBUL': 'Istanbul/Beşiktaş',
            'BAYRAMPAŞA/İSTANBUL': 'Istanbul/Bayrampaşa',
            'ÜMRANİYE/İSTANBUL': 'Istanbul/Ümraniye',
            'SOMA/MANİSA': 'Manisa/Soma',
            'BUCA/İZMİR': 'Izmir/Buca',
            'ORTAKÖY/AKSARAY': 'Aksaray/Ortaköy',
            'BORNOVA/İZMİR': 'Izmir/Bornova',
            'KEPEZ/ANTALYA': 'Antalya/Kepez',
            'BAHÇELİEVLER/İSTANBUL': 'Istanbul/Bahçelievler',
            'KARTAL/İSTANBUL': 'Istanbul/Kartal',
            'OSMANGAZİ/BURSA': 'Bursa/Osmangazi',
            'KAĞITHANE/İSTANBUL': 'Istanbul/Kağithane',
            'FATIH/İSTANBUL.': 'Istanbul/Fatih',
            'GÜNGÖREN/İSTANBUL': 'Istanbul/Güngören',
            'FATİH/İSTANBUL': 'Istanbul/Fatih',
            'DERİNCE/KOCAELİ': 'Kocaeli/Derince',
            'KÜÇÜKÇEKMECE/İSTANBUL': 'Istanbul/Küçükçekmece',
            'CANİK/SAMSUN': 'Samsun/Canik',
            'ELMADAĞ/ANKARA': 'Ankara/Elmadağ',
            'ATAŞEHİR/İSTANBUL': 'Istanbul/Ataşehir',
            'FATIH/İSTANBUL': 'Istanbul/Fatih',
            'SANCAKTEPE/İSTANBUL': 'Istanbul/Sancaktepe',
            'ŞİŞLİ/İSTANBUL': 'Istanbul/Şişli',
            'ODUNPAZARI/ESKİŞEHİR': 'Eskişehir/Odunpazarı',
            'ESENYURT/İSTANBUL': 'Istanbul/Esenyurt',
            'BULANCAK/GİRESUN': 'Giresun/Bulancak',
            'ALTINDAĞ/ANKARA': 'Ankara/Altındağ',
            'ŞEHİTKAMİL/GAZİANTEP': 'Gaziantep/Şehitkamil'
        }
        self.socioeconomic_data = None
        self.load_socioeconomic_data('data/formatted_data.json')
        
    def read_csv(self, file_path, remove_columns=None):
        df = pd.read_csv(file_path, low_memory=False)
        if remove_columns:
            df.drop(remove_columns, axis=1, inplace=True)
        return df
    
    def map_column(self, df, column_name, mapping_dict):
        df[column_name] = df[column_name].map(mapping_dict).fillna(df[column_name])
        return df
    
    def group_and_aggregate(self, df, group_by_column, agg_dict):
        return df.groupby(group_by_column).agg(agg_dict).reset_index()

    def merge(self, df1, df2, key, how='left'):
        return pd.merge(df1, df2, on=key, how=how)

    def load_socioeconomic_data(self, file_path):
        with open(file_path, 'r') as f:
            self.socioeconomic_data = json.load(f)

    def add_socioeconomic_info(self, df, city_column):
        df['SocioeconomicData'] = df[city_column].apply(lambda x: self.socioeconomic_data.get(x, None))
        return df
    
    def rename_columns(self, df, new_column_names):
        df.rename(columns=new_column_names, inplace=True)
        return df

    def process_data(self):
        df = self.read_csv('data/new_dataframe.csv', remove_columns=['Unnamed: 0'])
        rfm = self.read_csv('data/Customer_rfm.csv')
        churn_df = self.read_csv("data/churn_analysis.csv")
        
        df = self.map_column(df, 'Sehir', self.city_mapping_corrected)
        
        new_df = df[['id', 'Sehir', 'Tercih']].copy()
        new_df_grouped = self.group_and_aggregate(new_df, 'id', {
            'Sehir': 'first',  
            'Tercih': lambda x: list(set(x))
        })
        new_df_grouped['Tercih'] = new_df_grouped['Tercih'].apply(lambda x: x[0] if len(x) == 1 else x)
        
        merged_df = self.merge(rfm, new_df_grouped, 'id')
        result_df = self.merge(churn_df, merged_df, 'id', how='outer')
        
        result_df = self.add_socioeconomic_info(result_df, 'Sehir')
        
        column_names_mapping = {
            'id': 'CustomerID',
            'Churn': 'ChurnStatus',
            'Recency': 'RecencyScore',
            'Frequency': 'FrequencyScore',
            'Monetary': 'MonetaryValue',
            'R': 'RecencyRank',
            'F': 'FrequencyRank',
            'M': 'MonetaryRank',
            'RFM_Segment': 'RFMSegment',
            'RFM_Score': 'RFMScore',
            'Status': 'Segment',
            'Description': 'SegmentDescription',
            'Sehir': 'City',
            'Tercih': 'PreferredSolution',
            'socioeconomic_info': 'SocioeconomicData'
        }
        result_df = self.rename_columns(result_df, column_names_mapping)
        
        
        return result_df[['CustomerID', 'FirstTransactionDate', 'LastTransactionDate',
       'DaysSinceLastTransaction', 'ChurnStatus', 'TransactionFrequency', 'RecencyRank',
       'FrequencyRank', 'MonetaryRank', 'RFMScore','Segment', 'SegmentDescription', 'City', 'PreferredSolution',
       'SocioeconomicData']]

# %%
processor = DataProcessor()
final_df = processor.process_data()
final_df
# Out:
#     CustomerID FirstTransactionDate  LastTransactionDate  \
# 0    301002470  2015-09-18 14:35:04  2023-10-26 10:47:00
# 1    301002583  2014-09-25 10:08:52  2020-12-23 12:28:28
# 2    301003354  2022-11-21 18:05:00  2023-10-26 16:59:00
# 3    301006906  2016-01-29 11:00:43  2022-09-12 18:30:00
# 4    301009366  2019-06-27 17:31:14  2022-09-19 18:01:00
# 5    301009412  2016-08-26 11:00:35  2023-10-03 17:56:28
# 6    301009682  2016-05-19 10:29:01  2023-10-26 16:39:00
# 7    301010389  2016-06-15 15:12:25  2020-05-10 11:09:14
# 8    301012873  2018-12-07 12:52:00  2023-10-26 15:06:00
# 9    301014561  2017-08-10 14:22:03  2023-10-26 16:55:00
# 10   301015331  2017-02-09 11:21:52  2023-10-26 13:45:18
# 11   301018129  2018-09-15 15:53:45  2018-09-15 15:53:45
# 12   301019658  2017-05-26 17:37:46  2023-09-06 20:44:00
# 13   301020464  2022-06-11 10:39:00  2023-10-26 16:56:00
# 14   301021277  2017-07-24 14:19:13  2023-10-26 14:36:59
# 15   301023021  2017-11-07 16:48:45  2023-10-26 16:58:03
# 16   301024520  2017-12-18 17:52:53  2023-10-26 14:27:00
# 17   301024729  2019-05-17 16:30:00  2023-07-10 08:56:00
# 18   301025172  2018-01-11 08:37:44  2023-10-26 16:46:00
# 19   301025251  2018-05-02 15:16:56  2018-07-24 11:03:37
# 20   301025608  2018-01-29 16:12:25  2023-10-26 16:50:00
# 21   301026102  2018-02-22 20:16:36  2023-10-26 16:21:00
# 22   301026135  2018-08-30 17:47:27  2023-10-26 16:42:00
# 23   301026224  2018-02-20 19:35:09  2023-10-26 15:17:59
# 24   301026287  2018-03-06 19:02:42  2023-10-26 16:53:00
# 25   301026648  2018-03-13 17:58:26  2021-04-30 17:08:00
# 26   301026840  2018-03-22 14:46:46  2023-06-08 18:01:00
# 27   301026958  2019-07-24 16:33:59  2021-05-04 21:19:38
# 28   301027114  2018-05-05 20:10:08  2023-07-18 17:22:00
# 29   301029464  2018-08-17 19:15:49  2022-11-14 11:07:00
# 30   301029860  2018-09-14 08:26:00  2019-11-28 14:26:47
# 31   301030119  2018-10-20 14:48:26  2023-10-26 14:47:00
# 32   301030448  2018-10-24 16:11:46  2023-08-24 21:57:00
# 33   301031149  2018-11-19 14:12:00  2021-05-19 11:54:00
# 34   301031272  2018-11-21 14:13:00  2023-10-26 14:38:00
# 35   301031339  2018-11-26 17:46:00  2023-09-01 05:54:00
# 36   301032425  2018-12-29 14:51:00  2023-10-24 21:22:00
# 37   301032496  2018-12-28 16:19:46  2020-11-25 22:10:00
# 38   301033049  2019-02-01 16:40:00  2023-06-09 22:21:00
#
#     DaysSinceLastTransaction  ChurnStatus  TransactionFrequency  RecencyRank  \
# 0                          0        False            442.714286            3
# 1                       1037         True              9.533333            1
# 2                          0        False           2551.333333            3
# 3                        408         True            618.350649            1
# 4                        401         True            478.225000            2
# 5                         22        False              1.333333            3
# 6                          0        False            176.011765            3
# 7                       1264         True            510.424242            1
# 8                          0        False            616.800000            3
# 9                          0        False           1061.166667            3
# 10                         0        False            314.679012            3
# 11                      1867         True              2.000000            1
# 12                        49        False            762.633333            2
# 13                         0        False           1037.764706            3
# 14                         0        False            133.552632            3
# 15                         0        False            191.583333            3
# 16                         0        False            228.563380            3
# 17                       108         True            602.784314            2
# 18                         0        False            703.357143            3
# 19                      1920         True              2.500000            1
# 20                         0        False           2237.185714            3
# 21                         0        False            421.478261            3
# 22                         0        False            241.158730            3
# 23                         0        False            175.608696            3
# 24                         0        False            393.102941            3
# 25                       908         True            406.921053            1
# 26                       139         True           1222.796875            2
# 27                       904         True              1.666667            1
# 28                        99         True            278.269841            2
# 29                       346         True            346.230769            2
# 30                      1428         True           1411.615385            1
# 31                         0        False            292.084746            3
# 32                        62        False            344.471698            2
# 33                       890         True            935.161290            1
# 34                         0        False            563.866667            3
# 35                        55        False            523.301887            2
# 36                         1        False            889.237288            3
# 37                      1064         True            778.041667            1
# 38                       138         True            651.207547            2
#
#     FrequencyRank  MonetaryRank  RFMScore   Segment  \
# 0               3             4        10  Platinum
# 1               1             1         3     Bronz
# 2               4             3        10  Platinum
# 3               4             3         8     Altın
# 4               3             2         7     Gümüş
# 5               1             1         5     Gümüş
# 6               1             4         8     Altın
# 7               2             1         4     Bronz
# 8               3             2         8     Altın
# 9               3             3         9     Altın
# 10              3             4        10  Platinum
# 11              1             1         3     Bronz
# 12              3             4         9     Altın
# 13              2             3         8     Altın
# 14              1             4         8     Altın
# 15              1             4         8     Altın
# 16              2             1         6     Gümüş
# 17              4             2         8     Altın
# 18              4             3        10  Platinum
# 19              1             1         3     Bronz
# 20              4             4        11  Platinum
# 21              4             2         9     Altın
# 22              1             3         7     Gümüş
# 23              1             4         8     Altın
# 24              3             2         8     Altın
# 25              2             2         5     Gümüş
# 26              4             3         9     Altın
# 27              1             1         3     Bronz
# 28              2             2         6     Gümüş
# 29              2             1         5     Gümüş
# 30              2             2         5     Gümüş
# 31              2             3         8     Altın
# 32              2             1         5     Gümüş
# 33              3             1         5     Gümüş
# 34              4             4        11  Platinum
# 35              3             3         8     Altın
# 36              4             4        11  Platinum
# 37              2             2         5     Gümüş
# 38              4             2         8     Altın
#
#                                    SegmentDescription                   City  \
# 0   Yüksek değerli müşteri. Ortalamanın çok üzerin...         Samsun/Ilkadim
# 1   Düşük değerli müşteri. Ortalamanın çok altında...      Istanbul/Beşiktaş
# 2   Yüksek değerli müşteri. Ortalamanın çok üzerin...    Istanbul/Bayrampaşa
# 3   Orta değerli müşteri. Ortalamanın üzerinde sık...      Istanbul/Ümraniye
# 4   Düşük-orta değerli müşteri. Ortalamanın altınd...            Manisa/Soma
# 5   Düşük-orta değerli müşteri. Ortalamanın altınd...      Istanbul/Beşiktaş
# 6   Orta değerli müşteri. Ortalamanın üzerinde sık...             Izmir/Buca
# 7   Düşük değerli müşteri. Ortalamanın çok altında...        Aksaray/Ortaköy
# 8   Orta değerli müşteri. Ortalamanın üzerinde sık...          Izmir/Bornova
# 9   Orta değerli müşteri. Ortalamanın üzerinde sık...          Antalya/Kepez
# 10  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Istanbul/Bahçelievler
# 11  Düşük değerli müşteri. Ortalamanın çok altında...        Istanbul/Kartal
# 12  Orta değerli müşteri. Ortalamanın üzerinde sık...      Istanbul/Ümraniye
# 13  Orta değerli müşteri. Ortalamanın üzerinde sık...        Bursa/Osmangazi
# 14  Orta değerli müşteri. Ortalamanın üzerinde sık...     Istanbul/Kağithane
# 15  Orta değerli müşteri. Ortalamanın üzerinde sık...     Istanbul/Kağithane
# 16  Düşük-orta değerli müşteri. Ortalamanın altınd...         Istanbul/Fatih
# 17  Orta değerli müşteri. Ortalamanın üzerinde sık...      Istanbul/Güngören
# 18  Yüksek değerli müşteri. Ortalamanın çok üzerin...         Istanbul/Fatih
# 19  Düşük değerli müşteri. Ortalamanın çok altında...        Kocaeli/Derince
# 20  Yüksek değerli müşteri. Ortalamanın çok üzerin...  Istanbul/Küçükçekmece
# 21  Orta değerli müşteri. Ortalamanın üzerinde sık...  Istanbul/Küçükçekmece
# 22  Düşük-orta değerli müşteri. Ortalamanın altınd...           Samsun/Canik
# 23  Orta değerli müşteri. Ortalamanın üzerinde sık...         Ankara/Elmadağ
# 24  Orta değerli müşteri. Ortalamanın üzerinde sık...  Istanbul/Küçükçekmece
# 25  Düşük-orta değerli müşteri. Ortalamanın altınd...  Istanbul/Küçükçekmece
# 26  Orta değerli müşteri. Ortalamanın üzerinde sık...  Istanbul/Küçükçekmece
# 27  Düşük değerli müşteri. Ortalamanın çok altında...      Istanbul/Ataşehir
# 28  Düşük-orta değerli müşteri. Ortalamanın altınd...         Istanbul/Fatih
# 29  Düşük-orta değerli müşteri. Ortalamanın altınd...    Istanbul/Sancaktepe
# 30  Düşük-orta değerli müşteri. Ortalamanın altınd...         Istanbul/Şişli
# 31  Orta değerli müşteri. Ortalamanın üzerinde sık...   Eskişehir/Odunpazarı
# 32  Düşük-orta değerli müşteri. Ortalamanın altınd...  Istanbul/Küçükçekmece
# 33  Düşük-orta değerli müşteri. Ortalamanın altınd...          Izmir/Bornova
# 34  Yüksek değerli müşteri. Ortalamanın çok üzerin...        Istanbul/Kartal
# 35  Orta değerli müşteri. Ortalamanın üzerinde sık...      Istanbul/Esenyurt
# 36  Yüksek değerli müşteri. Ortalamanın çok üzerin...       Giresun/Bulancak
# 37  Düşük-orta değerli müşteri. Ortalamanın altınd...        Ankara/Altındağ
# 38  Orta değerli müşteri. Ortalamanın üzerinde sık...   Gaziantep/Şehitkamil
#
#            PreferredSolution  \
# 0            [ÖKC, CeptePos]
# 1                   CeptePos
# 2                        ÖKC
# 3            [ÖKC, CeptePos]
# 4            [ÖKC, CeptePos]
# 5                   CeptePos
# 6            [ÖKC, CeptePos]
# 7                   CeptePos
# 8                        ÖKC
# 9            [ÖKC, CeptePos]
# 10                  CeptePos
# 11                       ÖKC
# 12           [ÖKC, CeptePos]
# 13                       ÖKC
# 14                  CeptePos
# 15                  CeptePos
# 16                       ÖKC
# 17                       ÖKC
# 18                       ÖKC
# 19                  CeptePos
# 20                       ÖKC
# 21                       ÖKC
# 22                       ÖKC
# 23  [ÖKC, CeptePos, SadePos]
# 24                       ÖKC
# 25                       ÖKC
# 26                       ÖKC
# 27                  CeptePos
# 28                       ÖKC
# 29            [ÖKC, SadePos]
# 30                       ÖKC
# 31                       ÖKC
# 32                       ÖKC
# 33                       ÖKC
# 34                       ÖKC
# 35                       ÖKC
# 36            [ÖKC, SadePos]
# 37           [ÖKC, CeptePos]
# 38                       ÖKC
#
#                                     SocioeconomicData
# 0   {'YASLI/GENC ORANI': {'Genc': 50.0, 'Orta': 21...
# 1   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 2   {'Yaşlı/Genç Oranı': {'Genç': 65.0, 'Orta': 4....
# 3   {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 4   {'YAŞLI/GENÇ ORANI': {'Genç': 16.0, 'Orta': 31...
# 5   {'YAŞLI/GENÇ ORANI': {'Genç': 19.0, 'Orta': 22...
# 6   {'Yaşlı/Genç Oranı': {'Genç': 20.0, 'Orta': 53...
# 7   {'YAŞLI/GENÇ ORANI': {'Genç': 949.0, 'Orta': 9...
# 8   {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 9   {'Yaşlı/Genç Oranı': {'Genç': 68.0, 'Orta': 25...
# 10  {'Yaşlı/Genç Oranı': {'Genç': 18.0, 'Orta': 51...
# 11  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 12  {'YAŞLI/GENÇ ORANI': {'Genc': 95.5, 'Orta': 35...
# 13  {'Yaşlı/Genç Oranı': {'Genç': 52.0, 'Orta': 29...
# 14  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 15  {'Yaşlı/Genç Oranı': {'Genç': 36.0, 'Orta': 56...
# 16  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 17  {'YASLI/GENC ORANI': {'Genc': 55.0, 'Orta': 28...
# 18  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 19  {'YASLI/GENC ORANI': {'Genç': 52.0, 'Orta': 34...
# 20  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 21  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 22  {'YAŞLI/GENÇ ORANI': {'Genç': 61.0, 'Orta': 12...
# 23  {'Yaş Grupları': {'Genç': 14.0, 'Orta': 54.0, ...
# 24  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 25  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 26  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 27  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 33...
# 28  {'Yaşlı/Genç Oranı': {'Genç': 49.0, 'Orta': 35...
# 29  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 8....
# 30  {'Yaşlı/Genç Oranı': {'Genç': 23.0, 'Orta': 57...
# 31  {'YASLI/GENC ORANI': {'Genc': 52.0, 'Orta': 29...
# 32  {'Yaşlı/Genç Oranı': {'Genç': 55.0, 'Orta': 34...
# 33  {'Yaşlı/Genç Oranı': {'Genç': 50.0, 'Orta': 36...
# 34  {'Yaşlı/Genç Oranı': {'Genç': 56.0, 'Orta': 20...
# 35  {'yasli_genç_orani': {'genç': 96.0, 'orta': 94...
# 36  {'YASLI/GENC ORANI': {'Genç': 49.0, 'Orta': 20...
# 37  {'YASLI/GENC ORANI': {'Genc': 30.0, 'Orta': ''...
# 38  {'YASLI/GENC ORANI': {'Genc': 945.0, 'Orta': 6...

# %%
final_df.to_csv("data/odeal_customer_data_enhancement.csv")

# %% [markdown]
# ## 📑 Özelliklerin Detaylı Açıklaması
#
# - `CustomerID`: Her müşteriye özel belirlenen unique customer Id. 🆔
# - `FirstTransactionDate`: Müşterinin gerçekleştirdiği ilk işlemin tarihi. 🌟
# - `LastTransactionDate`: Müşterinin gerçekleştirdiği son işlemin tarihi. 🏷️
# - `DaysSinceLastTransaction`: En son işlemden itibaren geçen gün sayısı. 🗓️
# - `ChurnStatus`: müşterinin belirli bir süre içerisinde şirketle etkileşime geçip geçmediğini gösterir. Eğer müşteri, belirlenen 90 günlük süre zarfında şirketten herhangi bir hizmet almamış ve/veya işlem yapmamışsa, bu durum müşterinin şirketi terk etmiş olabileceğini işaret eder ve bu durumda ChurnStatus değeri True olarak belirlenir. Aksine, müşteri aktifse ve bu süre içerisinde işlem yapmışsa ChurnStatus değeri False olur, yani müşterinin hala aktif olduğunu ve şirketle ilişkisinin devam ettiğini gösterir. ✅❌
# - `TransactionFrequency`: Belirli bir dönemdeki işlem sayısı. 🔄
# - `RecencyRank`: Müşterinin en son işlemine göre sıralaması. 🆕
# - `FrequencyRank`: İşlem sıklığına göre müşterinin sıralaması. 📊
# - `MonetaryRank`: Toplam harcama tutarına göre müşterinin sıralaması. 💸
# - `RFMScore`: Yenilik/Güncellik (Recency), Sıklık (Frequency) ve Parasal (Monetary) değerlerin toplam puanı. 🔢
# - `Segment`: Müşterinin ait olduğu segment. 🎚️
#   - `Altın`: Çok yüksek değerli müşteriler, sık işlem yaparlar ve yüksek meblağlar harcarlar. 🥇
#   - `Gümüş`: Yüksek değerli müşteriler, sıklıkla işlem yaparlar ve orta düzeyde harcama yaparlar. 🥈
#   - `Platinum`: Orta seviye değerli müşteriler, ortalama sıklıkta işlem yaparlar ve ortalama harcama yaparlar. 🥉
#   - `Bronz`: Daha düşük değerli müşteriler, daha az sıklıkta işlem yaparlar ve daha az harcama yaparlar. 🏅
# - `SegmentDescription`: Müşteri segmentinin tanımı. 🔍
# - `City`: Müşterinin hizmet verdiği şehir. 🏙️
# - `PreferredSolution`: Müşterinin tercih ettiği hizmet/ler ya da ürün tipi. 💡
# - `SocioeconomicData`: Müşterinin hizmet verdiği şehir ile ilgili sosyoekonomik veriler. 📈
#
# Sonuç olarak oluşan yeni dataframe, müşteri sadakatini ve yaşam boyu değerini artırmak için stratejik planlamalar yapılmasına olanak tanır.
#
# ---
